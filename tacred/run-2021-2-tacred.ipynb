# %%
# !nvidia-smi
# Out:
# Mon Jun 19 02:53:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/CRL-Shaw-48
# Out:
# /content/drive/MyDrive/CRL-Shaw-48

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/CRL-Shaw-48'

# %%
# !pip3 install transformers
# !pip3 install gpytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 run_continual.py --dataname TACRED --encoder_epochs 20  --encoder_lr 1e-4 --prompt_pool_epochs 20  --prompt_pool_lr 1e-4 --classifier_epochs 300 --classifier_lr 3e-5 --replay_epochs 100 --seed 2021
# Out:
# Streaming output truncated to the last 5000 lines.
# train_prompted_classifier_epoch_137: 100% 192/192 [00:00<00:00, 428.80it/s, acc=1, loss=0.000294]
# train_prompted_classifier_epoch_138: 100% 192/192 [00:00<00:00, 431.14it/s, acc=0.999, loss=0.00125]
# train_prompted_classifier_epoch_139: 100% 192/192 [00:00<00:00, 429.66it/s, acc=1, loss=0.000444]
# train_prompted_classifier_epoch_140: 100% 192/192 [00:00<00:00, 430.54it/s, acc=1, loss=0.000348]
# train_prompted_classifier_epoch_141: 100% 192/192 [00:00<00:00, 434.60it/s, acc=1, loss=0.000296]
# train_prompted_classifier_epoch_142: 100% 192/192 [00:00<00:00, 425.51it/s, acc=1, loss=0.000128]
# train_prompted_classifier_epoch_143: 100% 192/192 [00:00<00:00, 424.64it/s, acc=1, loss=0.000238]
# train_prompted_classifier_epoch_144: 100% 192/192 [00:00<00:00, 426.27it/s, acc=1, loss=0.000221]
# train_prompted_classifier_epoch_145: 100% 192/192 [00:00<00:00, 432.97it/s, acc=1, loss=0.000257]
# ...
