# %%
# !nvidia-smi
# Out:
# Mon Jun 19 02:51:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    46W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CRL-Shaw-48
# Out:
# /content/drive/MyDrive/CRL-Shaw-48

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/CRL-Shaw-48'

# %%
# !pip3 install transformers
# !pip3 install gpytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 99.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.0/173.0 kB 24.7 MB/s eta 0:00:00
# ...

# %%
# !python3 run_continual.py --dataname TACRED --encoder_epochs 50  --encoder_lr 2e-5 --prompt_pool_epochs 20  --prompt_pool_lr 1e-4 --classifier_epochs 250 --classifier_lr 5e-5 --replay_epochs 50 --seed 2021
# Out:
# Streaming output truncated to the last 5000 lines.
# train_classifier_epoch_194: 100% 128/128 [00:00<00:00, 426.85it/s, acc=1, loss=0.000167]
# train_classifier_epoch_195: 100% 128/128 [00:00<00:00, 432.37it/s, acc=1, loss=0.000963]
# train_classifier_epoch_196: 100% 128/128 [00:00<00:00, 432.42it/s, acc=1, loss=8.23e-5]
# train_classifier_epoch_197: 100% 128/128 [00:00<00:00, 424.63it/s, acc=1, loss=3.47e-5]
# train_classifier_epoch_198: 100% 128/128 [00:00<00:00, 434.61it/s, acc=1, loss=4e-5]
# train_classifier_epoch_199: 100% 128/128 [00:00<00:00, 431.93it/s, acc=1, loss=0.000173]
# train_classifier_epoch_200: 100% 128/128 [00:00<00:00, 433.42it/s, acc=1, loss=2.13e-5]
# train_classifier_epoch_201: 100% 128/128 [00:00<00:00, 431.45it/s, acc=1, loss=8.09e-6]
# train_classifier_epoch_202: 100% 128/128 [00:00<00:00, 429.34it/s, acc=1, loss=9.32e-6]
# train_classifier_epoch_203: 100% 128/128 [00:00<00:00, 430.87it/s, acc=1, loss=4.63e-5]
# ...
