# %%
# !nvidia-smi
# Out:
# Sun Jun 18 21:46:25 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    47W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CRL-Shaw-48
# Out:
# /content/drive/MyDrive/CRL-Shaw-48

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/CRL-Shaw-48'

# %%
# !pip3 install transformers
# !pip3 install gpytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 62.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 79.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.0/173.0 kB 24.8 MB/s eta 0:00:00
# ...

# %%
# !python3 run_continual.py --dataname TACRED --encoder_epochs 10  --encoder_lr 1e-4 --prompt_pool_epochs 10  --prompt_pool_lr 1e-4 --classifier_epochs 100 --classifier_lr 5e-5 --replay_epochs 100 --seed 2321
# Out:
# hyper-parameter configurations:
# batch_size: 16
# bert_path: datasets/bert-base-uncased
# classifier_epochs: 100
# classifier_lr: 5.0e-05
# cov_mat: true
# data_path: datasets/
# dataname: TACRED
# device: !!python/object/apply:torch.device
# - cuda
# encoder_epochs: 10
# encoder_lr: 0.0001
# encoder_output_size: 768
# gmm_num_components: 1
# gpu: 0
# marker_size: 4
# max_grad_norm: 10
# max_length: 256
# max_num_models: 10
# n_gpu: 1
# num_tasks: 10
# num_workers: 0
# pattern: entity_marker
# prompt_embed_dim: 768
# prompt_init: uniform
# prompt_key_init: uniform
# prompt_length: 1
# prompt_pool_epochs: 10
# prompt_pool_lr: 0.0001
# prompt_pool_size: 80
# prompt_top_k: 8
# pull_constraint_coeff: 0.1
# rel_per_task: 4
# replay_epochs: 100
# replay_s_e_e: 256
# sample_freq: 5
# seed: 2321
# sgd_momentum: 0.1
# task_name: TACRED
# vocab_size: 30522
#
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...
